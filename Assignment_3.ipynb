# %% [markdown]
# <a href="https://colab.research.google.com/github/prnakyazze94/Data-602/blob/main/Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Write a program that prompts the user for a meal: breakfast, lunch, or dinner. Then using if statements and else statements print the user a message recommending a meal. For example, if the meal was breakfast, you could say something like, “How about some bacon and eggs?”
# The user may enter something else in, but you only have to respond to breakfast, lunch, or dinner.

# %%
meal = input("Enter a meal (breakfast, lunch, or dinner): ").strip().lower()

if meal == "breakfast":
    print("How about some bacon and eggs?")
elif meal == "lunch":
    print("How about a grilled chicken salad?")
elif meal == "dinner":
    print("How about some steak and roasted vegetables?")
# Out:
# Enter a meal (breakfast, lunch, or dinner): lunch
# How about a grilled chicken salad?

# %% [markdown]
# The mailroom has asked you to design a simple payroll program that calculates a student employee’s gross pay, including any overtime wages. If any employee works over 20 hours in a week, the mailroom pays them 1.5 times their regular hourly pay rate for all hours over 20.
# You should take in the user’s input for the number of hours worked, and their rate of pay.

# %%
# user inputs number of hours worked and rate of pay
hours_worked = float(input("Enter hours worked: "))
pay_rate = float(input("Enter hourly pay rate: "))

# Calculate student employee gross pay with overtime over 20 hours
if hours_worked > 20:
    regular_hours = 20
    overtime_hours = hours_worked - 20
    gross_pay = (regular_hours * pay_rate) + (overtime_hours * pay_rate * 1.5)
else:
    gross_pay = hours_worked * pay_rate

# Display the result
print(f"Gross pay: ${gross_pay:.2f}")
print(f"Overtime hours: {overtime_hours:.1f}")
# Out:
# Enter hours worked: 21
# Enter hourly pay rate: 20
# Gross pay: $430.00
# Overtime hours: 1.0

# %% [markdown]
# Write a function named times_ten. The function should accept an argument and display the product of its argument multiplied times 10.

# %%
def times_ten(number):
    """Accept an argument and display the product of it multiplied by 10."""
    result = number * 10
    print(result)


# Example
user_input = float(input("Enter a number: "))
times_ten(user_input)
# Out:
# Enter a number: 5
# 50.0

# %% [markdown]
# Find the errors, debug the program, and then execute to show the output.
#
# def main()
#       Calories1 = input( "How many calories are in the first food?")
#       Calories2 = input( "How many calories are in the first food?")
#       showCalories(calories1, calories2)
#
# def showCalories()
#    print(“The total calories you ate today”, format(calories1 + calories2,.2f))

# %%
def calories():
    # Convert input to float to allow arithmetic addition
    calories1 = float(input("How many calories are in the first food? "))
    calories2 = float(input("How many calories are in the second food? ")) # second food
    showCalories(calories1, calories2)

def showCalories(calories1, calories2):
    total = calories1 + calories2 # add the calories entered
    # Use standard quotes and string format specifier '.2f'
    print(f"The total calories you ate today: {total:.2f}")

# Call main to run the program
if __name__ == "__main__":
    calories()
# Out:
# How many calories are in the first food? 500
# How many calories are in the second food? 1500
# The total calories you ate today: 2000.00

# %% [markdown]
# Write a program that uses any loop (while or for) that calculates the total of the following series of numbers:
#          1/30 + 2/29 + 3/28 ............. + 30/1

# %%
# Initialize total sum
total = 0.0

# use a loop (for):numerator goes from 1 to 30, denominator goes from 30 down to 1
for i in range(1, 31):
    numerator = i
    denominator = 31 - i
    total += numerator / denominator

# Display the final sum rounded to two decimal places
print(f"Total: {total:.2f}")
# Out:
# Total: 93.84

# %% [markdown]
#  Write a function that computes the area of a triangle given its base and height.
# The formula for an area of a triangle is:
# AREA = 1/2 * BASE * HEIGHT

# %%
def triangle_area(base: float, height: float) -> float:
    """Calculate the area of a triangle given its base and height."""
    return 0.5 * base * height


# Example
base1 = 5
height1 = 4
base = float(input("Enter base: "))
height = float(input("Enter height: "))


area_example =triangle_area(base1, height1)
area = triangle_area(base, height)
print(area_example)
print(f"The area of the triangle is: {area:.2f}")
# Out:
# Enter base: 4
# Enter height: 4
# 10.0
# The area of the triangle is: 8.00
